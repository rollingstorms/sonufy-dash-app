# %%
a = [1,2,3,4,5]
b = 0
c = [6,7,8]

# %%
b, *a, *c
# Out:
# (0, 1, 2, 3, 4, 5, 6, 7, 8)

# %%
from src.Sonufy import *

def load_sonufy():
	model_path = 'model'
	sonufy = Sonufy(latent_dims=64, output_size=(64,64))
	sonufy.load_encoder(model_path)
	sonufy.load_db(model_path)

	return sonufy

sonufy = load_sonufy()
# Out:
# INFO: Initialized TensorFlow Lite runtime.
# Loaded tracks.
# Loaded genres.
# loaded scaler

# %%
search_input = 'venus television'
track, latents, this_track, audio_features = sonufy.search_for_recommendations(search_input, get_time_and_freq=True)
# Out:
# INFO: Applying 1 TensorFlow Lite delegate(s) lazily.
# /Users/michaelroth/miniforge3/envs/golden_env/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
track
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0S7Zur2g8YhqlzqtlYStli'},
#     'href': 'https://api.spotify.com/v1/artists/0S7Zur2g8YhqlzqtlYStli',
#     'id': '0S7Zur2g8YhqlzqtlYStli',
#     'name': 'Television',
#     'type': 'artist',
#     'uri': 'spotify:artist:0S7Zur2g8YhqlzqtlYStli'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/630o1rKTDsLeIPreOY1jqP'},
#   'href': 'https://api.spotify.com/v1/albums/630o1rKTDsLeIPreOY1jqP',
#   'id': '630o1rKTDsLeIPreOY1jqP',
#   'images': [{'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485118b36d985b0ae01163ca9cf6',
#     'width': 64},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0218b36d985b0ae01163ca9cf6',
#     'width': 300},
#    {'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27318b36d985b0ae01163ca9cf6',
#     'width': 640}],
#   'name': 'Marquee Moon',
#   'release_date': '1977-02-08',
#   'release_date_precision': 'day',
#   'total_tracks': 8,
#   'type': 'album',
#   'uri': 'spotify:album:630o1rKTDsLeIPreOY1jqP'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0S7Zur2g8YhqlzqtlYStli'},
#    'href': 'https://api.spotify.com/v1/artists/0S7Zur2g8YhqlzqtlYStli',
#    'id': '0S7Zur2g8YhqlzqtlYStli',
#    'name': 'Television',
#    'type': 'artist',
#    'uri': 'spotify:artist:0S7Zur2g8YhqlzqtlYStli'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 229026,
#  'explicit': False,
#  'external_ids': {'isrc': 'USEE10181882'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/3x0iCzjgf0v9lnwvAhU9P2'},
#  'href': 'https://api.spotify.com/v1/tracks/3x0iCzjgf0v9lnwvAhU9P2',
#  'id': '3x0iCzjgf0v9lnwvAhU9P2',
#  'is_local': False,
#  'name': 'Venus',
#  'popularity': 44,
#  'preview_url': 'https://p.scdn.co/mp3-preview/6201cc5dd8e7fefbbe9604571a5f1732291d48a7?cid=5f818fbc1c374e239ee0139163734165',
#  'track_number': 2,
#  'type': 'track',
#  'uri': 'spotify:track:3x0iCzjgf0v9lnwvAhU9P2'}

# %%
latents
# Out:
#    level_0   index                track_id                    filename  \
# 0        0  200160  04mFhwixjRtu091juEVrnP  04mFhwixjRtu091juEVrnP.npy
# 1        1  151119  7HwJIBgn20ju7eNO6nruJr  7HwJIBgn20ju7eNO6nruJr.npy
# 2        2  110016  11S2Wutl4HS1bciByXQzSP  11S2Wutl4HS1bciByXQzSP.npy
# 3        3  230000  50Hdn63Xa9EmXeGCFqlEFQ  50Hdn63Xa9EmXeGCFqlEFQ.npy
# 4        4   66461  3UtBeQARL1ane2vn1AIURY  3UtBeQARL1ane2vn1AIURY.npy
# 5        5  186988  2mBXevc9ST1bCgUzKMpjNw  2mBXevc9ST1bCgUzKMpjNw.npy
# 6        6  157163  1QLtJJvJ1sO4ApYXnd2XD9  1QLtJJvJ1sO4ApYXnd2XD9.npy
# 7        7  124220  3MHnAPdwufTWFRceiGmdiK  3MHnAPdwufTWFRceiGmdiK.npy
# 8        8    9494  1WANCADiaxgKE80z87U2tc  1WANCADiaxgKE80z87U2tc.npy
# 9        9  114490  4wnm6RatuekHSXJhpN4VgE  4wnm6RatuekHSXJhpN4VgE.npy
#
#    latent_0  latent_1  latent_2  latent_3  latent_4  latent_5  ...  \
# 0  0.177612  1.299805 -0.986328  0.103882 -1.317383 -1.568359  ...
# 1 -0.113220  1.658203 -1.717773  0.516602  0.167603 -2.806641  ...
# 2 -0.137207  0.275391 -0.438721  0.884277 -0.531250 -0.426025  ...
# 3 -0.398926  1.242188 -0.232178  0.479492 -0.858398  0.387451  ...
# 4 -0.030533  0.533203 -2.035156  0.264160  1.139648 -1.497070  ...
# 5  0.387695  1.190430 -0.360107 -0.270508 -1.837891 -0.542480  ...
# 6  0.713867  1.109375 -1.299805  0.495361  0.909668 -1.882812  ...
# 7 -0.529785  0.350586 -0.255615  1.081055 -0.468750 -0.997559  ...
# 8 -0.602051  1.507812  0.064270  0.890137 -0.557617 -1.593750  ...
# 9  0.304443  0.103271  0.516602  0.015991  0.163086 -0.880859  ...
#
#    track_popularity                             track_uri      artist_name  \
# 0                22  spotify:track:04mFhwixjRtu091juEVrnP   Jitterin' Jinn
# 1                12  spotify:track:7HwJIBgn20ju7eNO6nruJr  Arti & Mestieri
# 2                13  spotify:track:11S2Wutl4HS1bciByXQzSP         Magnapop
# 3                19  spotify:track:50Hdn63Xa9EmXeGCFqlEFQ           Shakti
# 4                21  spotify:track:3UtBeQARL1ane2vn1AIURY    Jose Asunción
# 5                18  spotify:track:2mBXevc9ST1bCgUzKMpjNw   Dr Sir Warrior
# 6                21  spotify:track:1QLtJJvJ1sO4ApYXnd2XD9       Milladoiro
# 7                14  spotify:track:3MHnAPdwufTWFRceiGmdiK    Los Lobotomys
# 8                11  spotify:track:1WANCADiaxgKE80z87U2tc          Chelsea
# 9                24  spotify:track:4wnm6RatuekHSXJhpN4VgE    Vince Tempera
#
#                 artist_id  artist_popularity  release_date  similarity  \
# 0  0bpoE3oA5qVID9ZNZAuUmg                 34    1991-10-01    0.778966
# 1  4kp3WqauG2CfMO6ZGXFXbh                 11    1974-06-24    0.768816
# 2  7dHWgQrSX118dV8s56RQDe                 21          None    0.765791
# 3  3CHhVBXSF764Uot9sN2i8L                 25    1977-10-24    0.737732
# 4  7dpev4PE7eNCTWIGiMrzjH                 27    2018-01-29    0.732628
# 5  3rhu0WA2F1lrBzJRZnzif9                 19    2011-08-16    0.732368
# 6  7jQt2VX8vXlhU9Eky0T1ag                 25    1982-05-25    0.731465
# 7  6jpJrLc8GCjGSxM8aK3hqH                 10    1997-08-02    0.729449
# 8  25O9uYqu9G9i3tVOcH03k6                 24    1979-10-01    0.729379
# 9  08U96YBZYW6NPyzE94Ksrr                 27    2014-06-17    0.729256
#
#    time_similarity  frequency_similarity  \
# 0         0.759088              0.815606
# 1         0.731155              0.848885
# 2         0.758501              0.783819
# 3         0.685399              0.827484
# 4         0.721032              0.759039
# 5         0.624902              0.916633
# 6         0.649567              0.865343
# 7         0.824436              0.534847
# 8         0.761086              0.665798
# 9         0.692362              0.795228
#
#                                        album_art_url
# 0  https://i.scdn.co/image/ab67616d0000b27318b36d...
# 1  https://i.scdn.co/image/ab67616d0000b2732c33a6...
# 2  https://i.scdn.co/image/ab67616d0000b273e8e38b...
# 3  https://i.scdn.co/image/ab67616d0000b273c7d255...
# 4  https://i.scdn.co/image/ab67616d0000b2735f1683...
# 5  https://i.scdn.co/image/ab67616d0000b27389c16b...
# 6  https://i.scdn.co/image/ab67616d0000b2732ab1a5...
# 7  https://i.scdn.co/image/ab67616d0000b2732c4b22...
# 8  https://i.scdn.co/image/ab67616d0000b273a3f6a5...
# 9  https://i.scdn.co/image/ab67616d0000b273de98ee...
#
# [10 rows x 80 columns]

# %%
this_track
# Out:
#    latent_0  latent_1  latent_2  latent_3  latent_4  latent_5  latent_6  \
# 0 -0.267694   0.48702 -0.390059  0.681599 -0.270861 -1.385494 -1.455817
#
#    latent_7  latent_8  latent_9  ...  latent_54  latent_55  latent_56  \
# 0  0.079184 -0.629078 -0.751216  ...   0.920993   1.098405  -0.800921
#
#    latent_57  latent_58  latent_59  latent_60  latent_61  latent_62  latent_63
# 0  -0.426495   -0.23268  -0.426794  -0.944332   1.095234  -0.053619   0.498836
#
# [1 rows x 64 columns]

# %%
list(*this_track.values)
# Out:
# [-0.2676944335843244,
#  0.4870197793316333,
#  -0.3900590201383092,
#  0.6815992762364081,
#  -0.2708611543946653,
#  -1.385494406461657,
#  -1.455817148410579,
#  0.0791844796457387,
#  -0.6290775964477331,
#  -0.7512156666546654,
#  1.2281592261510614,
#  0.4724061990900175,
#  -0.7616926076613783,
#  -1.5748199580460354,
#  0.5898275642273578,
#  0.16923031713453282,
#  0.10938567492952152,
#  -1.5325546568565944,
#  -0.03749862516936033,
#  0.6666654518831466,
#  1.3454800434432062,
#  -1.1997908760596252,
#  1.388735921683986,
#  -1.241070024562809,
#  -0.14832093832385765,
#  0.6340932974693838,
#  -0.29881199024691035,
#  -0.4891566902899355,
#  -0.6190322168829593,
#  0.8903724491498954,
#  1.3137659043262728,
#  1.174872225436566,
#  0.8208085140254329,
#  1.2309448572413093,
#  0.7865729767815858,
#  0.5053714566803253,
#  -0.7641928026662727,
#  0.7487592065412467,
#  0.7172977331120207,
#  -0.09063537175150618,
#  0.47934980102857305,
#  0.7436084317376745,
#  -0.6891210265503546,
#  0.14070069244057976,
#  0.42387050819756483,
#  -0.6566956298919737,
#  0.5927699581476593,
#  0.3794904086253231,
#  -0.5641410659514174,
#  -0.30493414697558957,
#  -0.22286074008054135,
#  -0.5814808633704747,
#  0.5189322423672845,
#  0.08059430090166682,
#  0.9209928993075545,
#  1.098404614073372,
#  -0.8009209156291289,
#  -0.42649536658552867,
#  -0.23267950711029875,
#  -0.42679400019807984,
#  -0.944331693317288,
#  1.0952344954528275,
#  -0.05361927882673097,
#  0.498836283543742]

# %%
audio_features
# Out:
# [{'danceability': 0.55,
#   'energy': 0.631,
#   'key': 0,
#   'loudness': -11.493,
#   'mode': 1,
#   'speechiness': 0.0385,
#   'acousticness': 0.000898,
#   'instrumentalness': 0.18,
#   'liveness': 0.0503,
#   'valence': 0.908,
#   'tempo': 114.553,
#   'type': 'audio_features',
#   'id': '3x0iCzjgf0v9lnwvAhU9P2',
#   'uri': 'spotify:track:3x0iCzjgf0v9lnwvAhU9P2',
#   'track_href': 'https://api.spotify.com/v1/tracks/3x0iCzjgf0v9lnwvAhU9P2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3x0iCzjgf0v9lnwvAhU9P2',
#   'duration_ms': 229027,
#   'time_signature': 4},
#  {'danceability': 0.598,
#   'energy': 0.689,
#   'key': 4,
#   'loudness': -10.216,
#   'mode': 0,
#   'speechiness': 0.0332,
#   'acousticness': 0.096,
#   'instrumentalness': 0.528,
#   'liveness': 0.313,
#   'valence': 0.51,
#   'tempo': 145.076,
#   'type': 'audio_features',
#   'id': '04mFhwixjRtu091juEVrnP',
#   'uri': 'spotify:track:04mFhwixjRtu091juEVrnP',
#   'track_href': 'https://api.spotify.com/v1/tracks/04mFhwixjRtu091juEVrnP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/04mFhwixjRtu091juEVrnP',
#   'duration_ms': 241267,
#   'time_signature': 4},
#  {'danceability': 0.251,
#   'energy': 0.416,
#   'key': 4,
#   'loudness': -12.56,
#   'mode': 0,
#   'speechiness': 0.032,
#   'acousticness': 0.00057,
#   'instrumentalness': 0.522,
#   'liveness': 0.191,
#   'valence': 0.238,
#   'tempo': 136.28,
#   'type': 'audio_features',
#   'id': '7HwJIBgn20ju7eNO6nruJr',
#   'uri': 'spotify:track:7HwJIBgn20ju7eNO6nruJr',
#   'track_href': 'https://api.spotify.com/v1/tracks/7HwJIBgn20ju7eNO6nruJr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7HwJIBgn20ju7eNO6nruJr',
#   'duration_ms': 278667,
#   'time_signature': 4},
#  {'danceability': 0.55,
#   'energy': 0.521,
#   'key': 0,
#   'loudness': -11.983,
#   'mode': 1,
#   'speechiness': 0.0296,
#   'acousticness': 0.0138,
#   'instrumentalness': 1.46e-05,
#   'liveness': 0.093,
#   'valence': 0.943,
#   'tempo': 115.905,
#   'type': 'audio_features',
#   'id': '11S2Wutl4HS1bciByXQzSP',
#   'uri': 'spotify:track:11S2Wutl4HS1bciByXQzSP',
#   'track_href': 'https://api.spotify.com/v1/tracks/11S2Wutl4HS1bciByXQzSP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/11S2Wutl4HS1bciByXQzSP',
#   'duration_ms': 176560,
#   'time_signature': 4},
#  {'danceability': 0.595,
#   'energy': 0.756,
#   'key': 9,
#   'loudness': -12.614,
#   'mode': 1,
#   'speechiness': 0.0923,
#   'acousticness': 0.187,
#   'instrumentalness': 0.866,
#   'liveness': 0.0937,
#   'valence': 0.933,
#   'tempo': 88.625,
#   'type': 'audio_features',
#   'id': '50Hdn63Xa9EmXeGCFqlEFQ',
#   'uri': 'spotify:track:50Hdn63Xa9EmXeGCFqlEFQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/50Hdn63Xa9EmXeGCFqlEFQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50Hdn63Xa9EmXeGCFqlEFQ',
#   'duration_ms': 420533,
#   'time_signature': 4},
#  {'danceability': 0.696,
#   'energy': 0.414,
#   'key': 0,
#   'loudness': -12.319,
#   'mode': 1,
#   'speechiness': 0.0642,
#   'acousticness': 0.615,
#   'instrumentalness': 0.823,
#   'liveness': 0.308,
#   'valence': 0.688,
#   'tempo': 96.315,
#   'type': 'audio_features',
#   'id': '3UtBeQARL1ane2vn1AIURY',
#   'uri': 'spotify:track:3UtBeQARL1ane2vn1AIURY',
#   'track_href': 'https://api.spotify.com/v1/tracks/3UtBeQARL1ane2vn1AIURY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3UtBeQARL1ane2vn1AIURY',
#   'duration_ms': 111456,
#   'time_signature': 4},
#  {'danceability': 0.741,
#   'energy': 0.625,
#   'key': 7,
#   'loudness': -6.149,
#   'mode': 1,
#   'speechiness': 0.0431,
#   'acousticness': 0.437,
#   'instrumentalness': 0.454,
#   'liveness': 0.314,
#   'valence': 0.914,
#   'tempo': 111.354,
#   'type': 'audio_features',
#   'id': '2mBXevc9ST1bCgUzKMpjNw',
#   'uri': 'spotify:track:2mBXevc9ST1bCgUzKMpjNw',
#   'track_href': 'https://api.spotify.com/v1/tracks/2mBXevc9ST1bCgUzKMpjNw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mBXevc9ST1bCgUzKMpjNw',
#   'duration_ms': 253267,
#   'time_signature': 4},
#  {'danceability': 0.439,
#   'energy': 0.394,
#   'key': 0,
#   'loudness': -10.911,
#   'mode': 1,
#   'speechiness': 0.0418,
#   'acousticness': 0.624,
#   'instrumentalness': 0.00441,
#   'liveness': 0.254,
#   'valence': 0.677,
#   'tempo': 101.933,
#   'type': 'audio_features',
#   'id': '1QLtJJvJ1sO4ApYXnd2XD9',
#   'uri': 'spotify:track:1QLtJJvJ1sO4ApYXnd2XD9',
#   'track_href': 'https://api.spotify.com/v1/tracks/1QLtJJvJ1sO4ApYXnd2XD9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1QLtJJvJ1sO4ApYXnd2XD9',
#   'duration_ms': 206333,
#   'time_signature': 4},
#  {'danceability': 0.331,
#   'energy': 0.538,
#   'key': 4,
#   'loudness': -9.542,
#   'mode': 0,
#   'speechiness': 0.0338,
#   'acousticness': 0.0588,
#   'instrumentalness': 0.736,
#   'liveness': 0.7,
#   'valence': 0.348,
#   'tempo': 112.336,
#   'type': 'audio_features',
#   'id': '3MHnAPdwufTWFRceiGmdiK',
#   'uri': 'spotify:track:3MHnAPdwufTWFRceiGmdiK',
#   'track_href': 'https://api.spotify.com/v1/tracks/3MHnAPdwufTWFRceiGmdiK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3MHnAPdwufTWFRceiGmdiK',
#   'duration_ms': 343267,
#   'time_signature': 4},
#  {'danceability': 0.321,
#   'energy': 0.758,
#   'key': 9,
#   'loudness': -10.129,
#   'mode': 0,
#   'speechiness': 0.0514,
#   'acousticness': 0.00158,
#   'instrumentalness': 1.12e-05,
#   'liveness': 0.0784,
#   'valence': 0.605,
#   'tempo': 169.257,
#   'type': 'audio_features',
#   'id': '1WANCADiaxgKE80z87U2tc',
#   'uri': 'spotify:track:1WANCADiaxgKE80z87U2tc',
#   'track_href': 'https://api.spotify.com/v1/tracks/1WANCADiaxgKE80z87U2tc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1WANCADiaxgKE80z87U2tc',
#   'duration_ms': 181867,
#   'time_signature': 4},
#  {'danceability': 0.421,
#   'energy': 0.478,
#   'key': 0,
#   'loudness': -9.705,
#   'mode': 1,
#   'speechiness': 0.029,
#   'acousticness': 0.314,
#   'instrumentalness': 0.85,
#   'liveness': 0.103,
#   'valence': 0.347,
#   'tempo': 102.847,
#   'type': 'audio_features',
#   'id': '4wnm6RatuekHSXJhpN4VgE',
#   'uri': 'spotify:track:4wnm6RatuekHSXJhpN4VgE',
#   'track_href': 'https://api.spotify.com/v1/tracks/4wnm6RatuekHSXJhpN4VgE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4wnm6RatuekHSXJhpN4VgE',
#   'duration_ms': 109227,
#   'time_signature': 3}]

# %%
track_ids = [track['id']] + list(latents['track_id'])

tracks = sonufy.spotify.tracks(track_ids)

# %%
tracks['tracks'][i]['album']['images'][-1]['url']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 tracks['tracks'][i]['album']['images'][-1]['url']
#
# NameError: name 'i' is not defined

# %%
tracks['tracks'][0]['album']['images']
# Out:
# [{'height': 64,
#   'url': 'https://i.scdn.co/image/ab67616d0000485118b36d985b0ae01163ca9cf6',
#   'width': 64},
#  {'height': 300,
#   'url': 'https://i.scdn.co/image/ab67616d00001e0218b36d985b0ae01163ca9cf6',
#   'width': 300},
#  {'height': 640,
#   'url': 'https://i.scdn.co/image/ab67616d0000b27318b36d985b0ae01163ca9cf6',
#   'width': 640}]

# %%
i=0
for col in latents.loc[i, sonufy.latent_cols]:
    print(col)
# Out:
# 0.1776
# 1.3
# -0.9863
# 0.1039
# -1.317
# -1.568
# -1.327
# 0.2426
# -1.222
# -0.57
# 0.3433
# -0.2632
# -0.0566
# -0.1833
# -0.692
# 0.0866
# 0.4548
# -1.843
# -0.3176
# 0.649
# 1.52
# -0.3184
# 1.274
# -0.745
# 0.6147
# 0.868
# -0.768
# -0.2003
# -0.4758
# 0.04678
# 2.39
# 0.632
# 1.238
# 1.434
# 1.015
# 0.11426
# -0.88
# 0.727
# 0.36
# -0.4897
# 0.747
# 1.219
# -0.6313
# 0.8237
# 0.267
# -0.9175
# 0.3
# 0.2583
# 0.2179
# -0.07825
# -0.821
# -0.806
# -0.3083
# -0.356
# 0.913
# 0.6943
# -0.522
# -0.1744
# 0.3574
# 0.1862
# -0.1873
# 1.353
# -0.085
# 0.0678

# %%
features_to_use = ['danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']

# %%
audio_features[0].keys()
# Out:
# dict_keys(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

# %%
audio_features[1]
# Out:
# {'danceability': 0.598,
#  'energy': 0.689,
#  'key': 4,
#  'loudness': -10.216,
#  'mode': 0,
#  'speechiness': 0.0332,
#  'acousticness': 0.096,
#  'instrumentalness': 0.528,
#  'liveness': 0.313,
#  'valence': 0.51,
#  'tempo': 145.076,
#  'type': 'audio_features',
#  'id': '04mFhwixjRtu091juEVrnP',
#  'uri': 'spotify:track:04mFhwixjRtu091juEVrnP',
#  'track_href': 'https://api.spotify.com/v1/tracks/04mFhwixjRtu091juEVrnP',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/04mFhwixjRtu091juEVrnP',
#  'duration_ms': 241267,
#  'time_signature': 4}
